# %% [markdown]
# <a href="https://colab.research.google.com/github/wertonr/Estudos/blob/main/Alura_Imersao_dados_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Aula 1 - 23/05/2022
#
# ![Imersao_Dados_Alura.jpg](data:image/jpeg;base64,...)
#
# Conceitos ensinados:
# - Importar biblioteca pandas
# - Ler arquivo csv através de url
# - Selecionar coluna/variavel especifica do conjunto de dados
# - Funções de soma e média de colunas/variaveis
# - Filtrar variavel desejada em determinada coluna
# - Plotar gráfico de barras com base em uma coluna

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                               Rua             Bairro     Cidade  Metragem  \
# 7467                   Rua Izonzo             Sacomã  São Paulo       100
# 5311  Rua Antônio Augusto Covello     Vila Monumento  São Paulo       200
# 9167               Rua Mont Kemel    Vila Água Funda  São Paulo       190
# 5746                          NaN       Vila Morumbi  São Paulo       805
# 5637      Rua Duílio Santo Suosso      Jardim Tenani  São Paulo       185
# 4822                          NaN      Cidade Jardim  São Paulo       709
# 7887                          NaN            Butantã  São Paulo       300
# 1421        Rua VeSão Pauloasiano        Vila Romana  São Paulo       170
# 8800                          NaN  Alto de Pinheiros  São Paulo       466
# 4421               Rua Conde D'Eu        Santo Amaro  São Paulo       605
#
#       Quartos  Banheiros  Vagas         Valor
# 7467        3          3      2    R$ 606.000
# 5311        3          3      2  R$ 1.300.000
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# # Desafios:

# %% [markdown]
# ## 1 - Realizar a média da metragem para cara um dos bairros (Paulo)

# %%
# Media de metragem de todos os bairros
dados.groupby('Bairro')['Metragem'].mean()
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %%
#Também posso adicionar o comando .to_frame() para deixar a visualização mais organizada e agradavel
media_metragem_bairros = dados.groupby('Bairro')['Metragem'].mean().to_frame()
media_metragem_bairros
# Out:
#                      Metragem
# Bairro
# Aclimação          253.056818
# Alto da Boa Vista  418.875000
# Alto da Lapa       294.337209
# Alto da Mooca      270.050000
# Alto de Pinheiros  433.444988
# ...                       ...
# Vila Água Funda    152.200000
# Água Branca        191.000000
# Água Fria          165.416667
# Água Funda         139.000000
# Água Rasa          340.250000
#
# [701 rows x 1 columns]

# %% [markdown]
# ## 2 - Duas formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)

# %%
#Primeira forma
dados.groupby('Bairro')

# %%
#Segunda forma
dados.loc[:,"Bairro"]
# Out:
# 0         Planalto Paulista
# 1        Jardim dos Estados
# 2           Jardim Reimberg
# 3            Jardim Morumbi
# 4                     Mooca
#                 ...
# 10003            Vila Sofia
# 10004       Bosque da Saúde
# 10005         Vila da Saúde
# 10006         Vila Oratório
# 10007           Vila Alpina
# Name: Bairro, Length: 10008, dtype: object

# %%
#Terceira forma
dados.query('Bairro == "nome do bairro"')
# Out:
# Empty DataFrame
# Columns: [Rua, Bairro, Cidade, Metragem, Quartos, Banheiros, Vagas, Valor]
# Index: []

# %% [markdown]
# ## 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)

# %% [markdown]
# ## 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)

# %%
#Estatisticas dos dados
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %%
#Estatísticas dos dados, com mais informações se dentro do parenteses adicionar all=include
dados.describe(include = 'all')
# Out:
#                       Rua             Bairro     Cidade       Metragem  \
# count                6574               9996      10008   10008.000000
# unique               3130                701          1            NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo            NaN
# freq                   24                409      10008            NaN
# mean                  NaN                NaN        NaN     442.300659
# std                   NaN                NaN        NaN    7515.379389
# min                   NaN                NaN        NaN      10.000000
# 25%                   NaN                NaN        NaN     173.000000
# 50%                   NaN                NaN        NaN     290.000000
# 75%                   NaN                NaN        NaN     460.250000
# max                   NaN                NaN        NaN  750000.000000
#
#              Quartos     Banheiros         Vagas         Valor
# ...

# %%
# Mas como o describe() não tem informação da mediana, segue abaixo a Mediana dos dados
dados.median()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# Metragem     290.0
# Quartos        3.0
# Banheiros      4.0
# Vagas          4.0
# dtype: float64

# %% [markdown]
# ## 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
# Descobrindo nome dos bairros que possuem observações sem o nome de Rua no DF.
sem_rua = dados['Rua'].isnull()  


dados_sem_rua = dados[sem_rua]
dados_sem_rua['Bairro'].unique()
# Out:
# array(['Jardim Morumbi', 'Jardim Luzitânia', 'Parque da Lapa',
#        'Chácara Santo Antônio (Zona Sul)', 'Jardim Guedala',
#        'Vila Arriete', 'Alto de Pinheiros', 'Planalto Paulista',
#        'Vila Moinho Velho', 'Brooklin Paulista', 'Sumaré',
#        'Jardim Paulista', 'Vila Gustavo', 'Jardim Trussardi',
#        'Vila Madalena', 'Jardim dos Estados', 'Vila Santos',
#        'Jardim Europa', 'Butantã', 'Jardim Paulistano',
#        'Jardim Petrópolis', 'Vila Mariana', 'Vila Aparecida', 'Siciliano',
#        'Alto da Lapa', 'Jardim da Glória', 'Morumbi', 'Vila Ida',
#        'Cidade Jardim', 'Cidade Dutra', 'Água Fria', 'Parque Boturussu',
#        'Belenzinho', 'Vila Sônia', 'Jardim Panorama', 'Jardim Ampliação',
#        'Lauzane Paulista', 'Vila Sabrina', 'Vila Olímpia',
#        'Jardim Franca', 'Jardim Sílvia (Zona Oeste)', 'Santo Amaro',
#        'Mooca', 'Jardim América', 'Interlagos', 'Pacaembu',
#        'Jardim Santo Amaro', 'Vila Matilde', 'Vila Prudente',
# ...

# %%
# Percentual dos bairros que possuem alguma observação sem nome de Rua no DF.
print(f"Quantidade de observações sem informação da rua: {sum(sem_rua)}")

num_bairros_sem_rua = len(dados_sem_rua['Bairro'].unique())
total_bairros = len(dados['Bairro'].unique())
percentual_bairros_sem_rua = round((num_bairros_sem_rua / total_bairros)*100)
print(f"O percentual de bairros que tem uma rua sem nome no banco de dados é de {percentual_bairros_sem_rua}%")
# Out:
# Quantidade de observações sem informação da rua: 3434
# O percentual de bairros que tem uma rua sem nome no banco de dados é de 56%

# %% [markdown]
# #Aula 02 - 24/05/2022
#
# Conceitos ensinados:
# - Separar informação de uma coluna em formato string;
# - Converter string em float;
# - Fazer gráfico com a biblioteca seaborn;

# %%
#Ver a informação do valor na primeira observação, lembrar que python começa do 0.
dados["Valor"][0]
# Out:
# 'R$ 7.000.000'

# %%
# Função split, usada para separar strings
dados["Valor"][0].split()
# Out:
# ['R$', '7.000.000']

# %%
# Fazer o split para toda a coluna
dados["Valor"].str.split()
# Out:
# 0          [R$, 7.000.000]
# 1          [R$, 3.700.000]
# 2            [R$, 380.000]
# 3            [R$, 685.000]
# 4            [R$, 540.000]
#                ...
# 10003        [R$, 665.000]
# 10004      [R$, 2.300.000]
# 10005      [R$, 1.050.000]
# 10006    [R$, 2.200, /Mês]
# 10007        [R$, 270.000]
# Name: Valor, Length: 10008, dtype: object

# %%
#Fazer com que o split divida em colunas
dados["Valor"].str.split(expand=True)
# Out:
#         0          1     2
# 0      R$  7.000.000  None
# 1      R$  3.700.000  None
# 2      R$    380.000  None
# 3      R$    685.000  None
# 4      R$    540.000  None
# ...    ..        ...   ...
# 10003  R$    665.000  None
# 10004  R$  2.300.000  None
# 10005  R$  1.050.000  None
# 10006  R$      2.200  /Mês
# 10007  R$    270.000  None
#
# [10008 rows x 3 columns]

# %%
# Ver os valores únicos
dados["Valor"].str.split(expand=True)[0].unique()
# Out:
# array(['R$'], dtype=object)

# %%
# Quantidade de valores diferentes na coluna
len(dados["Valor"].str.split(expand=True)[1].unique())
# Out:
# 1038

# %%
# Quantidade de informações diferentes na coluna 3 do split de valores
dados["Valor"].str.split(expand=True)[2].unique()
# Out:
# array([None, '/Mês', '/Ano', '/Dia'], dtype=object)

# %%
# Adicionando no banco de dados (dados) as três colunas criadas no split
dados[["Moeda","Valor_anuncio", "Tipo_anuncio"]] = dados["Valor"].str.split(expand=True)
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None

# %%
#Retirar as observações que estavam em formato de aluguel
dados_vendas = dados[dados["Tipo_anuncio"].isnull()]
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rua            6107 non-null   object
#  1   Bairro         9146 non-null   object
#  2   Cidade         9156 non-null   object
#  3   Metragem       9156 non-null   int64
#  4   Quartos        9156 non-null   int64
#  5   Banheiros      9156 non-null   int64
#  6   Vagas          9156 non-null   int64
#  7   Valor          9156 non-null   object
#  8   Moeda          9156 non-null   object
#  9   Valor_anuncio  9156 non-null   object
#  10  Tipo_anuncio   0 non-null      object
# dtypes: int64(4), object(7)
# memory usage: 858.4+ KB

# %%
#Como os valores estão usando ponto no formato brasileiro é preciso corrigi lo para deixar a variavel tipo numerica(inteiro ou float)

dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0        7000000.0
# 1        3700000.0
# 2         380000.0
# 3         685000.0
# 4         540000.0
#            ...
# 10002    1500000.0
# 10003     665000.0
# 10004    2300000.0
# 10005    1050000.0
# 10007     270000.0
# Name: Valor_anuncio, Length: 9156, dtype: float64

# %%
dados_vendas["Valor_anuncio_float"] = dados_vendas["Valor_anuncio"].str.replace(".","").astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dados_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9156 entries, 0 to 10007
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rua                  6107 non-null   object
#  1   Bairro               9146 non-null   object
#  2   Cidade               9156 non-null   object
#  3   Metragem             9156 non-null   int64
#  4   Quartos              9156 non-null   int64
#  5   Banheiros            9156 non-null   int64
#  6   Vagas                9156 non-null   int64
#  7   Valor                9156 non-null   object
#  8   Moeda                9156 non-null   object
#  9   Valor_anuncio        9156 non-null   object
#  10  Tipo_anuncio         0 non-null      object
#  11  Valor_anuncio_float  9156 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 929.9+ KB

# %%
#plotar histograma de valor de anuncio
dados_vendas['Valor_anuncio_float'].plot.hist()

# %%
#plotar histograma de valor de anuncio
dados_vendas['Valor_anuncio_float'].plot.hist(bins=50)

# %%
dados_vendas.describe()
# Out:
#             Metragem      Quartos    Banheiros        Vagas  \
# count    9156.000000  9156.000000  9156.000000  9156.000000
# mean      434.416230     3.446811     3.797073     3.960135
# std      7856.422978     1.048944     1.967873     2.601022
# min        10.000000     1.000000     1.000000     1.000000
# 25%       168.000000     3.000000     2.000000     2.000000
# 50%       276.000000     3.000000     4.000000     4.000000
# 75%       450.000000     4.000000     5.000000     5.000000
# max    750000.000000    16.000000    40.000000    50.000000
#
#        Valor_anuncio_float
# count         9.156000e+03
# mean          3.052203e+06
# std           3.944208e+06
# min           1.300000e+04
# 25%           8.900000e+05
# 50%           1.800000e+06
# 75%           3.500000e+06
# max           6.500000e+07

# %%
# Mudar a quantidade de casas decimais que aparecem 
pd.set_option("display.precision",2)
dados_vendas.describe()
# Out:
#         Metragem  Quartos  Banheiros    Vagas  Valor_anuncio_float
# count    9156.00  9156.00    9156.00  9156.00             9.16e+03
# mean      434.42     3.45       3.80     3.96             3.05e+06
# std      7856.42     1.05       1.97     2.60             3.94e+06
# min        10.00     1.00       1.00     1.00             1.30e+04
# 25%       168.00     3.00       2.00     2.00             8.90e+05
# 50%       276.00     3.00       4.00     4.00             1.80e+06
# 75%       450.00     4.00       5.00     5.00             3.50e+06
# max    750000.00    16.00      40.00    50.00             6.50e+07

# %%
# Outra maneira de alterar a quantidade de casas decimais que aparecem 
pd.set_option("display.float_format", lambda x: '%.2f' % x)
dados_vendas.describe()
# Out:
#        Metragem  Quartos  Banheiros   Vagas  Valor_anuncio_float  Valor_m2
# count   9156.00  9156.00    9156.00 9156.00              9156.00   9156.00
# mean     434.42     3.45       3.80    3.96           3052202.96   8004.07
# std     7856.42     1.05       1.97    2.60           3944208.19   5291.32
# min       10.00     1.00       1.00    1.00             13000.00      9.33
# 25%      168.00     3.00       2.00    2.00            890000.00   4750.00
# 50%      276.00     3.00       4.00    4.00           1800000.00   6500.00
# 75%      450.00     4.00       5.00    5.00           3500000.00   9453.78
# max   750000.00    16.00      40.00   50.00          65000000.00  80000.00

# %%
#Incluir mais estatisticas no describe
dados_vendas.describe(include="all")
# Out:
#                       Rua             Bairro     Cidade  Metragem  Quartos  \
# count                6107               9146       9156   9156.00  9156.00
# unique               3006                697          1       NaN      NaN
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo       NaN      NaN
# freq                   24                369       9156       NaN      NaN
# mean                  NaN                NaN        NaN    434.42     3.45
# std                   NaN                NaN        NaN   7856.42     1.05
# min                   NaN                NaN        NaN     10.00     1.00
# 25%                   NaN                NaN        NaN    168.00     3.00
# 50%                   NaN                NaN        NaN    276.00     3.00
# 75%                   NaN                NaN        NaN    450.00     4.00
# max                   NaN                NaN        NaN 750000.00    16.00
#
# ...

# %%
#Describe quando as variaveis são do tipo objeto/string
dados_vendas[["Rua","Bairro","Cidade"]].describe()
# Out:
#                       Rua             Bairro     Cidade
# count                6107               9146       9156
# unique               3006                697          1
# top     Rua Alberto Faria  Alto de Pinheiros  São Paulo
# freq                   24                369       9156

# %%
# Plotando gráfico com a biblioteca seaborn
import seaborn as sns
sns.set()
sns.histplot(data = dados_vendas, x = "Valor_anuncio_float")

# %%
# Plotando gráfico com a biblioteca seaborn, adicionando curva de aproximação
import seaborn as sns
sns.set()
sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde = True)

# %%
# Plotando gráfico usando comandos do matplotlib
import seaborn as sns
import matplotlib.pyplot as plt

sns.set()
plt.figure(figsize=(10,8))#tamanho do gráfico
grafico = sns.histplot(data = dados_vendas, x = "Valor_anuncio_float", kde = True)
grafico.set_title("Histograma do valor do imóvel")#adicionando título
plt.xlim((-50,10000000))
plt.show()

# %% [markdown]
# #Desafios 2:

# %% [markdown]
# ## 1 - Criar uma escala de valores em milhões

# %%
dados_vendas['Valor_milhoes'] = dados_vendas['Valor_anuncio_float'].apply(lambda x: x/1000000)
dados_vendas['Valor_milhoes']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0       7.00
# 1       3.70
# 2       0.38
# 3       0.69
# 4       0.54
#         ...
# 10002   1.50
# 10003   0.67
# 10004   2.30
# 10005   1.05
# 10007   0.27
# Name: Valor_milhoes, Length: 9156, dtype: float64

# %% [markdown]
# ## 2 - Deixar o gráfico do histograma de valores legível (alterar labels, cores, título, escala)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_context("poster", font_scale=1, rc={"grid.linewidth": 5, "axes.linewidth": 5, })
plt.figure(figsize=(13,8))#tamanho do gráfico
grafico = sns.histplot(data = dados_vendas, x = "Valor_milhoes", kde = True)
grafico.set_title("Quantidade por valor dos Imóveis")#adicionando título
ax.set_xlabel("Valor em Milhões")
ax.set_ylabel("Quantidade")
plt.xlim((0,15))
plt.show()

# %% [markdown]
# ## 3 - Preço do metro quadrado por bairro e plotar em um gráfico ideal

# %%
valor_medio_bairro = dados_vendas.groupby('Bairro').mean()['Valor_anuncio_float']
metragem_media_bairro = dados_vendas.groupby('Bairro').mean()['Metragem']
preco_metroquadrado = valor_medio_bairro/metragem_media_bairro
preco_metroquadrado.to_frame()
# Out:
#                          0
# Bairro
# Aclimação          7162.69
# Alto da Boa Vista  5708.74
# Alto da Lapa       6961.30
# Alto da Mooca      4385.00
# Alto de Pinheiros 11126.34
# ...                    ...
# Vila Água Funda    4283.84
# Água Branca        7065.77
# Água Fria          5604.53
# Água Funda         3920.86
# Água Rasa          3846.91
#
# [697 rows x 1 columns]

# %% [markdown]
# ## 4 - Explorar as bibliotecas de visualizações e colocar as suas conclusão

# %%
plt.figure(figsize=(13, 8), dpi=300)
ax = sns.heatmap(dados_vendas.corr())
ax.figure.suptitle("Correlação entre Variáveis")
# Out:
# Text(0.5, 0.98, 'Correlação entre Variáveis')

# %% [markdown]
# Observa-se no gráfico de correlação acima, que a variável metragem tem correlação proxima de 0 com todas as variaveis. Todavia, pelo senso comum, deveria ter uma correlação do tamanho do apartamento com a quantidade de quartos, banheiros e valor.
#
# Além disso, com exceção das variaveis criadas (valor_m2,valor_milhoes_valor_anuncio float), que por se tratarem da mesma informação base, vai ocasionar a correlação. Apenas as variáveis banheiro e quartos tem uma correlação superior a 0.5 (observado tb pela tabela abaixo).

# %%
print(dados_vendas.corr())
# Out:
#                      Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Metragem                 1.00     0.03       0.05   0.03                 0.03
# Quartos                  0.03     1.00       0.52   0.39                 0.33
# Banheiros                0.05     0.52       1.00   0.45                 0.43
# Vagas                    0.03     0.39       0.45   1.00                 0.47
# Valor_anuncio_float      0.03     0.33       0.43   0.47                 1.00
# Valor_m2                -0.01     0.13       0.22   0.19                 0.74
# Valor_Milhoes            0.03     0.33       0.43   0.47                 1.00
# Valor_milhoes            0.03     0.33       0.43   0.47                 1.00
#
#                      Valor_m2  Valor_Milhoes  Valor_milhoes
# Metragem                -0.01           0.03           0.03
# Quartos                  0.13           0.33           0.33
# Banheiros                0.22           0.43           0.43
# ...

# %% [markdown]
# ## 5 - Pesquisar um visualização para analisar os quartis, mediana e outliers

# %% [markdown]
# O gráfico resposta desse desafio é o boxplot. Nele podemos ver os outliers (bolinhas), a mediana (linha que corta o retangulo) e os quantis (linha superior e inferior do retangulo). Conforme demonstrado no gráfico abaixo.

# %%
# o gráfico resposta desse desafio é o boxplot. Nele podemos ver os outliers (bolinhas), a mediana (linha que corta o retangulo)
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros"), x="Bairro", y="Valor_anuncio_float")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# # Aula 03 - 25.05

# %%
#visualizar as primeiras linhas
dados_vendas.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# 0        4          8      6  R$ 7.000.000    R$     7.000.000         None
# 1        4          4      4  R$ 3.700.000    R$     3.700.000         None
# 2        4          3      2    R$ 380.000    R$       380.000         None
# 3        3          2      4    R$ 685.000    R$       685.000         None
# 4        3          2      2    R$ 540.000    R$       540.000         None
#
#    Valor_anuncio_float
# 0            7000000.0
# ...

# %%
#Criando coluna "valor_m2"
dados_vendas["Valor_m2"] = dados_vendas["Valor_anuncio_float"]/dados_vendas["Metragem"]
dados_vendas.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio Tipo_anuncio  \
# ...

# %%
dados_vendas.groupby("Bairro").mean()
# Out:
#                      Metragem   Quartos  Banheiros     Vagas  \
# Bairro
# Aclimação          246.164557  3.265823   3.037975  2.911392
# Alto da Boa Vista  418.875000  4.125000   5.125000  4.625000
# Alto da Lapa       299.250000  3.150000   3.850000  4.000000
# Alto da Mooca      270.050000  3.300000   2.600000  3.650000
# Alto de Pinheiros  429.853659  3.937669   4.829268  4.951220
# ...                       ...       ...        ...       ...
# Vila Água Funda    152.200000  2.600000   2.200000  2.600000
# Água Branca        173.583333  3.083333   3.250000  2.250000
# Água Fria          165.416667  2.833333   3.416667  2.500000
# Água Funda         139.000000  3.000000   2.500000  2.000000
# Água Rasa          186.166667  2.666667   2.000000  3.666667
#
#                    Valor_anuncio_float      Valor_m2
# Bairro
# Aclimação                 1.763200e+06   7656.169465
# Alto da Boa Vista         2.391250e+06   5849.569011
# Alto da Lapa              2.083169e+06   7606.728080
# ...

# %%
dados_bairro = dados_vendas.groupby("Bairro").sum()
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         1.392928e+08
# Alto da Boa Vista      3351       33         41     37         1.913000e+07
# Alto da Lapa          23940      252        308    320         1.666535e+08
# Alto da Mooca          5401       66         52     73         2.368340e+07
# Alto de Pinheiros    158616     1453       1782   1827         1.764816e+09
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13         3.260000e+06
# Água Branca            2083       37         39     27         1.471800e+07
# Água Fria              1985       34         41     30         1.112500e+07
# Água Funda              278        6          5      4         1.090000e+06
# Água Rasa              1117       16         12     22         4.297000e+06
#
#                        Valor_m2
# Bairro
# ...

# %%
dados_bairro["Valor_m2_bairro"] = dados_bairro["Valor_anuncio_float"]/dados_bairro["Metragem"]
dados_bairro
# Out:
#                    Metragem  Quartos  Banheiros  Vagas  Valor_anuncio_float  \
# Bairro
# Aclimação             19447      258        240    230         1.392928e+08
# Alto da Boa Vista      3351       33         41     37         1.913000e+07
# Alto da Lapa          23940      252        308    320         1.666535e+08
# Alto da Mooca          5401       66         52     73         2.368340e+07
# Alto de Pinheiros    158616     1453       1782   1827         1.764816e+09
# ...                     ...      ...        ...    ...                  ...
# Vila Água Funda         761       13         11     13         3.260000e+06
# Água Branca            2083       37         39     27         1.471800e+07
# Água Fria              1985       34         41     30         1.112500e+07
# Água Funda              278        6          5      4         1.090000e+06
# Água Rasa              1117       16         12     22         4.297000e+06
#
# ...

# %%
dados_vendas.groupby("Bairro").mean().loc["Vila Mariana"]
# Out:
# Metragem               2.312367e+02
# Quartos                3.390533e+00
# Banheiros              3.236686e+00
# Vagas                  2.952663e+00
# Valor_anuncio_float    1.771160e+06
# Valor_m2               7.913155e+03
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro.loc["Vila Mariana"]
# Out:
# Metragem               3.907900e+04
# Quartos                5.730000e+02
# Banheiros              5.470000e+02
# Vagas                  4.990000e+02
# Valor_anuncio_float    2.993260e+08
# Valor_m2               1.337323e+06
# Valor_m2_bairro        7.659510e+03
# Name: Vila Mariana, dtype: float64

# %%
dados_bairro["Valor_m2_bairro"]["Vila Mariana"]
# Out:
# 7659.510222881855

# %%
top_bairros = dados_vendas["Bairro"].value_counts()[:10].index

# %%
dados_bairro.reset_index(inplace = True)
dados_bairro
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 0            Aclimação     19447      258        240    230
# 1    Alto da Boa Vista      3351       33         41     37
# 2         Alto da Lapa     23940      252        308    320
# 3        Alto da Mooca      5401       66         52     73
# 4    Alto de Pinheiros    158616     1453       1782   1827
# ..                 ...       ...      ...        ...    ...
# 692    Vila Água Funda       761       13         11     13
# 693        Água Branca      2083       37         39     27
# 694          Água Fria      1985       34         41     30
# 695         Água Funda       278        6          5      4
# 696          Água Rasa      1117       16         12     22
#
#      Valor_anuncio_float      Valor_m2  Valor_m2_bairro
# 0           1.392928e+08  6.048374e+05      7162.688384
# 1           1.913000e+07  4.679655e+04      5708.743659
# 2           1.666535e+08  6.085382e+05      6961.299081
# ...

# %%
dados_bairro.query("Bairro in @top_bairros")
# Out:
#                 Bairro  Metragem  Quartos  Banheiros  Vagas  \
# 4    Alto de Pinheiros    158616     1453       1782   1827
# 19   Brooklin Paulista     70002      778        862    832
# 57       Cidade Jardim    132220      789       1008   1172
# 155      Jardim Europa    118898      795        993   1056
# 168     Jardim Guedala    972212     1443       2027   2161
# 187      Jardim Leonor     97141      697        941    902
# 227    Jardim Paulista    130283     1028       1231   1171
# 338           Pacaembu    100285      774        889   1028
# 396  Planalto Paulista     59250      636        768    713
# 564      Vila Madalena     66250      739        786    712
#
#      Valor_anuncio_float      Valor_m2  Valor_m2_bairro
# 4           1.764816e+09  4.158623e+06     11126.342330
# 19          4.757968e+08  1.627342e+06      6796.902788
# 57          1.164211e+09  1.635693e+06      8805.104372
# 155         2.414173e+09  4.192164e+06     20304.571145
# ...

# %%
plt.figure(figsize=(10, 8))
ax = sns.barplot(x="Bairro", y="Valor_m2_bairro", data=dados_bairro.query("Bairro in @top_bairros"))
ax.tick_params(axis='x', rotation=45)

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros"), x="Bairro", y="Valor_anuncio_float")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 8))
ax = sns.boxplot(data = dados_vendas.query("Bairro in @top_bairros & Metragem < 30000"), x="Bairro", y="Metragem")
ax.tick_params(axis='x', rotation=45)
plt.show()

# %%
dados_vendas
# Out:
#                                   Rua              Bairro     Cidade  \
# 0               Avenida Itacira, 255    Planalto Paulista  São Paulo
# 1      Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo
# 2                     Rua Alba Valdez     Jardim Reimberg  São Paulo
# 3                                 NaN      Jardim Morumbi  São Paulo
# 4            Rua Tobias Barreto, 195                Mooca  São Paulo
# ...                               ...                 ...        ...
# 10002                   Avenida Odila   Planalto Paulista  São Paulo
# 10003                      Rua Tapuçu          Vila Sofia  São Paulo
# 10004                   Rua Guararema     Bosque da Saúde  São Paulo
# 10005               Rua Estero Belaco       Vila da Saúde  São Paulo
# 10007      Rua Barão de Tramandaí, 0          Vila Alpina  São Paulo
#
#        Metragem  Quartos  Banheiros  Vagas         Valor Moeda Valor_anuncio  \
# ...

# %%
ibge_url = "https://gist.githubusercontent.com/tgcsantos/85f8c7b0a2edbc3e27fcad619b37d886/raw/a4954781e6bca9cb804062a3eea0b3b84679daf4/Basico_SP1.csv"
pd.read_csv(ibge_url)
# Out:
#                                                                                                                                                Cod_setor;Cod_Grandes Regi�es;Nome_Grande_Regiao;Cod_UF;Nome_da_UF ;Cod_meso;Nome_da_meso;Cod_micro;Nome_da_micro;Cod_RM;Nome_da_RM;Cod_municipio;Nome_do_municipio;Cod_distrito;Nome_do_distrito;Cod_subdistrito;Nome_do_subdistrito;Cod_bairro;Nome_do_bairro;Situacao_setor;Tipo_setor;V001;V002;V003;V004;V005;V006;V007;V008;V009;V010;V011;V012;
# 355030801000001;3;"Regi�o Sudeste";35;"S�o Paul... 01;2 32;2091 32;8532451           78;2164 55;8673276 78;1227 41;4285771 99;1713 75;5152087                                               86.0
# 355030801000002;3;"Regi�o Sudeste";35;"S�o Paul... 98;2 09;1650 09;3983441           31;1717 44;4030519 99;1045 78;2572133 32;1468 08;2991546                                               94.0
# ...

# %% [markdown]
# # Desafio 3:

# %% [markdown]
# ## 1 - Tentar vincular dados do IBGE com os dados de imóveis.

# %% [markdown]
# ## 2 - Tratar os outliers e comparar com os resultados.

# %% [markdown]
# ## 3 - Agrupar por mais de uma categoria e realizar as análises.

# %% [markdown]
# ## 4 - Organize o colab para deixar com cara de projeto.
